# %%
# Basic  Functions of Computer Vsion

# %%
#  Example  :  1    To split an image in  red blue and green color

import cv2

image = cv2.imread('dataset/2.jpg')
B, G, R = cv2.split(image)

# Corresponding channels are seperated

cv2.imshow("original", image)
cv2.waitKey(0)

cv2.imshow("blue", B)
cv2.waitKey(0)

cv2.imshow("Green", G)
cv2.waitKey(0)

cv2.imshow("red", R)
cv2.waitKey(0)

cv2.destroyAllWindows()

# %%
#  Example  :  2    To split another image in  red blue and green color

import cv2

image = cv2.imread('dataset/1.jfif')
B, G, R = cv2.split(image)

# Corresponding channels are seperated

cv2.imshow("original", image)
cv2.waitKey(0)

cv2.imshow("Green", G)
cv2.waitKey(0)

cv2.imshow("Blue", B)
cv2.waitKey(0)

cv2.imshow("red", R)
cv2.waitKey(0)

cv2.destroyAllWindows()

# %%
#  Example  :  3   To split an image in  red blue and green color

import cv2

image = cv2.imread('dataset/b.jpg')
B, G, R = cv2.split(image)

# Corresponding channels are seperated

cv2.imshow("original", image)
cv2.waitKey(0)

cv2.imshow("blue", B)
cv2.waitKey(0)

cv2.imshow("Green", G)
cv2.waitKey(0)

cv2.imshow("red", R)
cv2.waitKey(0)

cv2.destroyAllWindows()

# %% [markdown]
# ###  Drawing a Line & Displaying

# %%
# Example : 1 Drawing a line and displaying in an image

import cv2

path="C:/Users/hp/dataset/image.jpg"
image = cv2.imread(path)
window_name = 'Image'

# Start coordinate,(0, 0)represents the top left corner of image
start_point = (10, 20)

# End coordinate, here (250, 250)represents the bottom right corner of image
end_point = (50, 20)
color = (0, 255, 0)  # Represent Green color (0,255,255) - yellow color 
thickness = 9
image = cv2.line(image, start_point, end_point, color, thickness)
cv2.imshow(window_name, image)

cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ### Drawing a Circle

# %%
# Example : 2 Drawing a circle and displaying in an image

import cv2

path = "C:/Users/hp/dataset/image.jpg"
image = cv2.imread(path)

window_name = 'Image'
center_coordinates = (120, 90)
radius = 40
color = ( 0,255, 0)
thickness = 3
image = cv2.circle(image, center_coordinates, radius, color, thickness)
cv2.imshow(window_name, image)

cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# Example : 3 Drawing a circle and displaying in an image

import cv2

path = "C:/Users/hp/dataset/image.jpg"
image = cv2.imread(path)

window_name = 'Image'
center_coordinates = (120, 50)
radius = 20
color = ( 255,255, 0)
thickness = 2
image = cv2.circle(image, center_coordinates, radius, color, thickness)
cv2.imshow(window_name, image)

cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ### Drawing a Rectangle

# %%
# Example : 4 Drawing a rectangle and displaying in an image

import cv2

path = "C:/Users/hp/dataset/image.jpg"
image = cv2.imread(path)

window_name = 'Image'

# Start coordinate, here (5, 5)
# represents the top left corner of rectangle

start_point = (5, 5)

# Ending coordinate, here (220, 220)
# represents the bottom right corner of rectangle

end_point = (220, 25)
color = (255, 0, 0)
thickness = 2
image = cv2.rectangle(image, start_point, end_point, color, thickness)
cv2.imshow(window_name, image)

cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# Example : 4 Drawing a rectangle and displaying in an image

import cv2

path = "C:/Users/hp/dataset/image.jpg"
image = cv2.imread(path)

window_name = 'Image'

# Start coordinate, here (10, 20)
# represents the top left corner of rectangle

start_point = (15, 15)

# Ending coordinate, here (220, 220)
# represents the bottom right corner of rectangle

end_point = (220, 25)
color = (255, 0, 0)
thickness = 2
image = cv2.rectangle(image, start_point, end_point, color, thickness)
cv2.imshow(window_name, image)

cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ### Writing string on an image

# %%
# Example : 5 Writing string [text]  on an  image

import cv2

path = "C:/Users/hp/dataset/image.jpg"
image = cv2.imread(path)

window_name = 'Image'
font = cv2.FONT_HERSHEY_SIMPLEX
org = (50, 50)
fontScale = 1 # fontScale
color = (255, 0, 0)

# Line thickness of 2 px
thickness = 2

# Using cv2.putText() method
image = cv2.putText(image, 'Syed Imran', org, font,fontScale, color, thickness, cv2.LINE_AA)


cv2.imshow(window_name, image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# Example : 6 Writing string [text]  on an  image

import cv2

path = "C:/Users/hp/dataset/image.jpg"
image = cv2.imread(path)

window_name = 'Image'
font = cv2.FONT_HERSHEY_SIMPLEX
org = (50, 50)
fontScale = 0.5 # fontScale
color = (255, 0, 0)

# Line thickness of 2 px
thickness = 2

# Using cv2.putText() method
image = cv2.putText(image, 'Syed Imran', org, font,fontScale, color, thickness, cv2.LINE_AA)


cv2.imshow(window_name, image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ### Find counters (boundries)

# %%
import cv2
import numpy as np

# Let's load a simple image 

image = cv2.imread('C:/Users/hp/dataset/image.jpg')
cv2.waitKey(0)

# Grayscale
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# Find Canny edges
edged = cv2.Canny(gray, 30, 200)
cv2.waitKey(0)

# Finding Contours
# Use a copy of the image e.g. edged.copy()
# since findContours alters the image
contours, hierarchy = cv2.findContours(edged,
	cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_NONE)

cv2.imshow('Canny Edges After Contouring', edged)
cv2.waitKey(0)


print("Number of Contours found = " + str(len(contours)))

# Draw all contours
# -1 signifies drawing all contours
cv2.drawContours(image, contours, -1, (255, 0, 0), 3)

cv2.imshow('Contours', image)

cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# Number of Contours found = 2

# %%
import cv2
import numpy as np

# Let's load a simple image 

image = cv2.imread('C:/Users/hp/dataset/image.jpg')
cv2.waitKey(0)

# Grayscale
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# Find Canny edges
edged = cv2.Canny(gray, 10, 200)
cv2.waitKey(0)

cv2.imshow('Canny Edges After Contouring', edged)
cv2.waitKey(0)

cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# Example : 2 boundries of an elephant
import cv2
import numpy as np

# Let's load a simple image 

image = cv2.imread('C:/Users/hp/Elephants1.jpg')
cv2.waitKey(0)

# Grayscale
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# Find Canny edges
edged = cv2.Canny(gray, 150, 250)
cv2.waitKey(0)

cv2.imshow('Canny Edges After Contouring', edged)
cv2.waitKey(0)

cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# # Blurring an image

# %%
# Example: 1

# importing libraries
import cv2
import numpy as np

image = cv2.imread('dataset/1.jfif')

cv2.imshow('Original Image', image)
cv2.waitKey(0)

# Gaussian Blur
Gaussian = cv2.GaussianBlur(image, (7, 7), 0)
cv2.imshow('Gaussian Blurring', Gaussian)
cv2.waitKey(0)

# Median Blur
median = cv2.medianBlur(image, 5)
cv2.imshow('Median Blurring', median)
cv2.waitKey(0)


# Bilateral Blur
bilateral = cv2.bilateralFilter(image, 9, 75, 75)
cv2.imshow('Bilateral Blurring', bilateral)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# Example: 2

# importing libraries
import cv2
import numpy as np

image = cv2.imread('dataset/2.jpg')

cv2.imshow('Original Image', image)
cv2.waitKey(0)

# Gaussian Blur
Gaussian = cv2.GaussianBlur(image, (7, 7), 0)
cv2.imshow('Gaussian Blurring', Gaussian)
cv2.waitKey(0)

# Median Blur
median = cv2.medianBlur(image, 5)
cv2.imshow('Median Blurring', median)
cv2.waitKey(0)


# Bilateral Blur
bilateral = cv2.bilateralFilter(image, 9, 75, 75)
cv2.imshow('Bilateral Blurring', bilateral)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# # Border to an image

# %%
# Example : 1

import cv2

path = 'C:/Users/hp/dataset/image.jpg'
image = cv2.imread(path)
window_name = 'Image'

image = cv2.copyMakeBorder(image, 5, 5, 10, 10, cv2.BORDER_CONSTANT, None, value = 1)
cv2.imshow(window_name, image)

cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# Example : 2

import cv2

path = 'C:/Users/hp/dataset/image.jpg'
image = cv2.imread(path)
window_name = 'Image'

image = cv2.copyMakeBorder(image, 25, 5, 10, 10, cv2.BORDER_CONSTANT, None, value = 1) # Topside value 25
cv2.imshow(window_name, image)

cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# Example : 3

import cv2

path = 'C:/Users/hp/dataset/image.jpg'
image = cv2.imread(path)
window_name = 'Image'

image = cv2.copyMakeBorder(image, 15, 25, 10, 10, cv2.BORDER_CONSTANT, None, value = 1) # bottom side value 25
cv2.imshow(window_name, image)

cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# Example : 4

import cv2

path = 'C:/Users/hp/dataset/image.jpg'
image = cv2.imread(path)
window_name = 'Image'

image = cv2.copyMakeBorder(image, 15, 5, 25, 10, cv2.BORDER_CONSTANT, None, value = 1) # Left side value 25
cv2.imshow(window_name, image)

cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# Example : 4

import cv2

path = 'C:/Users/hp/dataset/image.jpg'
image = cv2.imread(path)
window_name = 'Image'

image = cv2.copyMakeBorder(image, 15, 5, 10, 25, cv2.BORDER_CONSTANT, None, value = 1) # right side value 25
cv2.imshow(window_name, image)

cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# Example : 5  reflecting images

import cv2

path = 'C:/Users/hp/dataset/image.jpg'
image = cv2.imread(path)
window_name = 'Image'

image = cv2.copyMakeBorder(image, 100, 100, 50, 50, cv2.BORDER_REFLECT)
cv2.imshow(window_name, image)

cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# Example : 6  reflecting images

import cv2

path = 'C:/Users/hp/dataset/image.jpg'
image = cv2.imread(path)
window_name = 'Image'

image = cv2.copyMakeBorder(image, 200, 100, 150, 150, cv2.BORDER_REFLECT)
cv2.imshow(window_name, image)

cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# # Convert color spaces

# %%
# Example : 1

import cv2

path = 'C:/Users/hp/dataset/image.jpg'
src = cv2.imread(path)

window_name = 'Image'

image = cv2.cvtColor(src, cv2.COLOR_BGR2GRAY )
#image = cv2.cvtColor(src, cv2.COLOR_BGR2HSV )
# Displaying the image
cv2.imshow(window_name, image)

cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# Example : 2

import cv2

path = 'C:/Users/hp/dataset/image.jpg'
src = cv2.imread(path)

window_name = 'Image'

#image = cv2.cvtColor(src, cv2.COLOR_BGR2GRAY )
image = cv2.cvtColor(src, cv2.COLOR_BGR2HSV )
# Displaying the image
cv2.imshow(window_name, image)

cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# # Scaling

# %%
# Example -1 resizing an image

import cv2
import numpy as np

FILE_NAME = "C:/Users/hp/dataset/image.jpg"
try:
    # Read image from disk.
    img = cv2.imread(FILE_NAME)

    # Get number of pixel horizontally and vertically.
    (height, width) = img.shape[:2]

    # Specify the size of image along with interploation methods.
    # cv2.INTER_AREA is used for shrinking, whereas cv2.INTER_CUBIC
    # is used for zooming.
    res = cv2.resize(img, (int(width / 2), int(height / 2)), interpolation = cv2.INTER_CUBIC)



    # Shape of image in terms of pixels
    (rows, cols) = img.shape[:2]

    # getRotationMatrix2D creates a matrix needed for transformation.
    # We want matrix for rotation w.r.t center to 45 degree without scaling.
    # M = cv2.getRotationMatrix2D((cols / 2, rows / 2), 35, 1)
    # res = cv2.warpAffine(img, M, (cols, rows))


    # Write image back to disk.
    cv2.imwrite('result.jpg', res)
    cv2.imshow('input', img)
    cv2.waitKey(0)
    cv2.imshow('output', res)
    cv2.waitKey(0)

except IOError:
  print('Error while reading files !!!')

# %%
# Example -2  rotating an image

import cv2
import numpy as np

FILE_NAME = "C:/Users/hp/dataset/image.jpg"
try:
    # Read image from disk.
    img = cv2.imread(FILE_NAME)

    # Get number of pixel horizontally and vertically.
    (height, width) = img.shape[:2]

    # Specify the size of image along with interploation methods.
    # cv2.INTER_AREA is used for shrinking, whereas cv2.INTER_CUBIC
    # is used for zooming.
    # res = cv2.resize(img, (int(width / 2), int(height / 2)), interpolation = cv2.INTER_CUBIC)



    # Shape of image in terms of pixels
    (rows, cols) = img.shape[:2]

    # getRotationMatrix2D creates a matrix needed for transformation.
    # We want matrix for rotation w.r.t center to 45 degree without scaling.
    M = cv2.getRotationMatrix2D((cols / 2, rows / 2), 35, 1)
    res = cv2.warpAffine(img, M, (cols, rows))


    # Write image back to disk.
    cv2.imwrite('result.jpg', res)
    cv2.imshow('input', img)
    cv2.waitKey(0)
    cv2.imshow('output', res)
    cv2.waitKey(0)

except IOError:
  print('Error while reading files !!!')

# %%
# Example -3  resizing and rotating an image

import cv2
import numpy as np

FILE_NAME = "C:/Users/hp/dataset/image.jpg"
try:
    # Read image from disk.
    img = cv2.imread(FILE_NAME)

    # Get number of pixel horizontally and vertically.
    (height, width) = img.shape[:2]

    # Specify the size of image along with interploation methods.
    # cv2.INTER_AREA is used for shrinking, whereas cv2.INTER_CUBIC
    # is used for zooming.
    res = cv2.resize(img, (int(width / 2), int(height / 2)), interpolation = cv2.INTER_CUBIC)



    # Shape of image in terms of pixels
    (rows, cols) = img.shape[:2]

    # getRotationMatrix2D creates a matrix needed for transformation.
    # We want matrix for rotation w.r.t center to 45 degree without scaling.
    M = cv2.getRotationMatrix2D((cols / 2, rows / 2), 35, 1)
    res = cv2.warpAffine(img, M, (cols, rows))


    # Write image back to disk.
    cv2.imwrite('result.jpg', res)
    cv2.imshow('input', img)
    cv2.waitKey(0)
    cv2.imshow('output', res)
    cv2.waitKey(0)

except IOError:
  print('Error while reading files !!!')

# %%
# Example -4  resizing and rotating an image i.e  60 degree without scaling

import cv2
import numpy as np

FILE_NAME = "C:/Users/hp/dataset/image.jpg"
try:
    # Read image from disk.
    img = cv2.imread(FILE_NAME)

    # Get number of pixel horizontally and vertically.
    (height, width) = img.shape[:2]

    # Specify the size of image along with interploation methods.
    # cv2.INTER_AREA is used for shrinking, whereas cv2.INTER_CUBIC
    # is used for zooming.
    res = cv2.resize(img, (int(width / 2), int(height / 2)), interpolation = cv2.INTER_CUBIC)



    # Shape of image in terms of pixels
    (rows, cols) = img.shape[:2]

    # getRotationMatrix2D creates a matrix needed for transformation.
    # We want matrix for rotation w.r.t center to 45 degree without scaling.
    M = cv2.getRotationMatrix2D((cols / 2, rows / 2), 60, 1)
    res = cv2.warpAffine(img, M, (cols, rows))


    # Write image back to disk.
    cv2.imwrite('result.jpg', res)
    cv2.imshow('input', img)
    cv2.waitKey(0)
    cv2.imshow('output', res)
    cv2.waitKey(0)

except IOError:
  print('Error while reading files !!!')

# %% [markdown]
# # Edge Detection

# %%
import cv2
import numpy as np

FILE_NAME = 'image.jpg'
try:
    # Read image from disk.
    img = cv2.imread(FILE_NAME)

    # Canny edge detection.
    edges = cv2.Canny(img, 100, 200)

    # Write image back to disk.
    cv2.imwrite('result.jpg', edges)
    cv2.imshow("output",edges)
    cv2.waitKey(0)
except IOError:
    print ('Error while reading files !!!')

# %% [markdown]
# # demonstrate erosion and dilation of images.

# %%
# Python program to demonstrate erosion and
# dilation of images.
import cv2
import numpy as np

# Reading the input image
img = cv2.imread('image.jpg', 0)

# Taking a matrix of size 5 as the kernel
kernel = np.ones((5,5), np.uint8)

# The first parameter is the original image,
# kernel is the matrix with which image is
#convolved and third parameter is the number
# of iterations, which will determine how much
# you want to erode/dilate a given image.
img_erosion = cv2.erode(img, kernel, iterations=1)
img_dilation = cv2.dilate(img, kernel, iterations=1)

cv2.imshow('Input', img)
cv2.imshow('Erosion', img_erosion)
cv2.imshow('Dilation', img_dilation)

cv2.waitKey(0)
# Out:
# -1
